# %% [markdown]
# # Red neuronal con compuerta AND

# %%
import matplotlib.pyplot as plt
import numpy as np

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %% [markdown]
# Como vemos en la siguiente imagen, esta es una compuerta AND
# <img src="and.png">

# %% [markdown]
# Entonces, para los datos que le pasaremos a la red neuronal utilizaremos estos datos de la siguiente forma:
# * Los datos de entrada que se ven en la imagen, serán pasados como pares de datos (p.e. [0,0]) para el X de entrenamiento.
# * Los datos de salida, serán pasados para el Y de entrenamiento.

# %%
x_train = np.array([[0,0],[0,1],[1,0],[1,1]])
Y_train = np.array([[0],[0],[0],[1]])

# %% [markdown]
# El modelo de perceptrón multicapa MLP, se definiría de la siguiente manera, utilizando la función de activación ReLU y sigmoid

# %%
kerass = keras.Sequential()
kerass.add(layers.Dense(2, input_dim = 2, activation = 'relu'))
kerass.add(layers.Dense(1, activation = 'sigmoid'))
kerass.compile(optimizer = keras.optimizers.Adam(0.01), loss='mean_squared_error', metrics = ['accuracy'])

# %%
fit_history = kerass.fit(x_train, Y_train, epochs = 400, batch_size = 1)
# Out:
# Epoch 1/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2957 - accuracy: 0.7500
# Epoch 2/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2839 - accuracy: 0.7500
# Epoch 3/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2771 - accuracy: 0.7500
# Epoch 4/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2691 - accuracy: 0.7500
# Epoch 5/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2619 - accuracy: 0.7500
# Epoch 6/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2532 - accuracy: 0.7500
# Epoch 7/400
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2498 - accuracy: 0.7500
# Epoch 8/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2398 - accuracy: 0.7500
# Epoch 9/400
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2297 - accuracy: 0.7500
# Epoch 10/400
# ...

# %%
#resultados = kerass.evaluate(x_train)

# %%
def visualizacion(fit_history):
    epochs = [i for i in range(400)]
    fig, ax = plt.subplots(1,2)
    train_acc = fit_history.history["accuracy"]
    train_loss = fit_history.history["loss"]
    #val_acc = fit_history.history["val_accuracy"]
    #val_loss = fit_history.history["val_loss"]
    fig.set_size_inches(16, 9)
    
    ax[0].plot(epochs, train_acc, "go-", label="Accuracy entrenamiento")
    #ax[0].plot(epochs, val_acc, "ro-", label="Accuracy validacion")
    ax[0].set_title("Entrenamiento y validacion")
    ax[0].legend()
    ax[0].set_xlabel("Epochs")
    ax[0].set_ylabel("Accuracy")
    
    ax[1].plot(epochs, train_loss, "go-", label="Accuracy entrenamiento loss")
    #ax[1].plot(epochs, val_loss, "ro-", label="Accuracy validacion loss")
    ax[1].set_title("Entrenamiento y validacion Loss")
    ax[1].legend()
    ax[1].set_xlabel("Epochs")
    ax[1].set_ylabel("Loss")
    
    plt.show()

# %%
visualizacion(fit_history)

# %%
loss_curve = fit_history.history['loss']
accuracy_curve = fit_history.history['accuracy']
plt.plot(accuracy_curve, label = 'Precisión')
plt.plot(loss_curve, label = 'Perdida')
plt.legend(loc = 'lower left')
plt.title('Resultado del Entrenamiento')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Recuperamos bias and weights de la capa oculta:

# %%
pesos_HL, sesgos_HL = kerass.layers[0].get_weights()
pesos_HL, sesgos_HL
# Out:
# (array([[ 2.0616972,  1.1238103],
#         [ 0.5574404, -2.5876992]], dtype=float32),
#  array([-0.55870247,  1.4646956 ], dtype=float32))

# %% [markdown]
# Recuperamos bias and weights de la capa de salida:

# %%
pesos_OL, sesgos_OL = kerass.layers[1].get_weights()
pesos_OL, sesgos_OL
# Out:
# (array([[ 2.6666446],
#         [-2.1360168]], dtype=float32),
#  array([-2.2671835], dtype=float32))
